# %%
# testing with json object without having to make api calls

# %%
YOUR_API_KEY = ""

# %%
match_id = "NA1_4995853430"

# %%
import requests
match_info = requests.get("https://americas.api.riotgames.com/lol/match/v5/matches/%s?api_key=%s" %(match_id, YOUR_API_KEY))

# %%
match_info = match_info.json()
print(match_info['info'])
# Out:
# {'endOfGameResult': 'GameComplete', 'gameCreation': 1715482527758, 'gameDuration': 1879, 'gameEndTimestamp': 1715484429283, 'gameId': 4995853430, 'gameMode': 'CLASSIC', 'gameName': 'teambuilder-match-4995853430', 'gameStartTimestamp': 1715482550073, 'gameType': 'MATCHED_GAME', 'gameVersion': '14.9.580.2108', 'mapId': 11, 'participants': [{'allInPings': 0, 'assistMePings': 5, 'assists': 9, 'baronKills': 0, 'basicPings': 0, 'bountyLevel': 0, 'challenges': {'12AssistStreakCount': 0, 'abilityUses': 385, 'acesBefore15Minutes': 0, 'alliedJungleMonsterKills': 2, 'baronBuffGoldAdvantageOverThreshold': 1, 'baronTakedowns': 1, 'blastConeOppositeOpponentCount': 0, 'bountyGold': 600, 'buffsStolen': 0, 'completeSupportQuestInTime': 0, 'controlWardsPlaced': 1, 'damagePerMinute': 939.9504876605798, 'damageTakenOnTeamPercentage': 0.21632081088747676, 'dancedWithRiftHerald': 0, 'deathsByEnemyChamps': 3, 'dodgeSkillShotsSmallWindow': 13, 'doubleAces': 0, 'dragonTakedowns': 0, 'earliestBaron': 1315.576
# ...

# %%
print(match_info['info']['participants'][2]['summonerName'])
# Out:
# teddioo

# %%
wr = ['Lee Sin', '51.74% 889', 'Viego', '47.64% 466', 'Nidalee', '48.72% 234', 'Lillia', '43.26% 215', 'Jarvan IV', '51.94% 206', 'Karthus', '43.35% 203', 'Vi', '43.22% 199', "Kha'Zix", '43.52% 193', 'Taliyah', '45.26% 190', 
'Zac', '52.49% 181', 'Diana', '47.49% 179', 'Graves', '50.56% 178', 'Xin Zhao', '42.29% 175', 'Brand', '49.08% 163', "Rek'Sai", '42.50% 160', 'Kindred', '46.50% 157', 'Rengar', '48.25% 143', 'Kayn', '45.07% 142', 'Shaco', '47.86% 140', 'Gragas', '51.24% 121', 'Ekko', '44.54% 119', "Bel'Veth", '48.31% 118', 'Hecarim', '40.91% 110', 'Sejuani', '44.55% 101', 'Skarner', '47.56% 82', 'Master Yi', '53.09% 81', 'Briar', '60.49% 81', 'Nocturne', '45.00% 80', 'Sylas', '61.04% 77', 'Amumu', '47.95% 73', 'Volibear', '49.30% 71', 'Fiddlesticks', '51.56% 64', 'Ivern', '31.25% 64', 'Evelynn', '42.62% 61', 'Warwick', '54.39% 57', 'Jax', '44.64% 56', 'Elise',
 '51.92% 52', 'Udyr', '42.31% 52', 'Talon', '42.86% 49', 'Rammus', '36.96% 46', 'Nunu & Willump', '35.56% 45', 'Wukong', '55.81% 43', 'Morgana', '44.44% 36']

# %%
for x in range(1, len(wr), 2):
    wr[x] = wr[x][:5]
print(wr)
# Out:
# ['Lee Sin', '51.74', 'Viego', '47.64', 'Nidalee', '48.72', 'Lillia', '43.26', 'Jarvan IV', '51.94', 'Karthus', '43.35', 'Vi', '43.22', "Kha'Zix", '43.52', 'Taliyah', '45.26', 'Zac', '52.49', 'Diana', '47.49', 'Graves', '50.56', 'Xin Zhao', '42.29', 'Brand', '49.08', "Rek'Sai", '42.50', 'Kindred', '46.50', 'Rengar', '48.25', 'Kayn', '45.07', 'Shaco', '47.86', 'Gragas', '51.24', 'Ekko', '44.54', "Bel'Veth", '48.31', 'Hecarim', '40.91', 'Sejuani', '44.55', 'Skarner', '47.56', 'Master Yi', '53.09', 'Briar', '60.49', 'Nocturne', '45.00', 'Sylas', '61.04', 'Amumu', '47.95', 'Volibear', '49.30', 'Fiddlesticks', '51.56', 'Ivern', '31.25', 'Evelynn', '42.62', 'Warwick', '54.39', 'Jax', '44.64', 'Elise', '51.92', 'Udyr', '42.31', 'Talon', '42.86', 'Rammus', '36.96', 'Nunu & Willump', '35.56', 'Wukong', '55.81', 'Morgana', '44.44']

# %%
for x in range(0, len(wr), 2):
    key = x
    value = x+1
    
    print(wr[key], wr[value])
# Out:
# Lee Sin 51.74
# Viego 47.64
# Nidalee 48.72
# Lillia 43.26
# Jarvan IV 51.94
# Karthus 43.35
# Vi 43.22
# Kha'Zix 43.52
# Taliyah 45.26
# Zac 52.49
# Diana 47.49
# Graves 50.56
# Xin Zhao 42.29
# Brand 49.08
# Rek'Sai 42.50
# Kindred 46.50
# Rengar 48.25
# Kayn 45.07
# Shaco 47.86
# Gragas 51.24
# Ekko 44.54
# Bel'Veth 48.31
# Hecarim 40.91
# Sejuani 44.55
# Skarner 47.56
# Master Yi 53.09
# Briar 60.49
# Nocturne 45.00
# Sylas 61.04
# Amumu 47.95
# Volibear 49.30
# Fiddlesticks 51.56
# Ivern 31.25
# Evelynn 42.62
# Warwick 54.39
# Jax 44.64
# Elise 51.92
# Udyr 42.31
# Talon 42.86
# Rammus 36.96
# Nunu & Willump 35.56
# Wukong 55.81
# Morgana 44.44
